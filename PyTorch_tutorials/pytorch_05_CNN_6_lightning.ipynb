# %% [markdown]
# <div style="line-height:1.2;">
#
# <h1 style="color:#BF66F2; margin-bottom: 0.3em;"> Convolutional Neural Networks in PyTorch 6 </h1>
#
# <h4 style="margin-top: 0.3em; margin-bottom: 1em;"> PyTorch Lightning tutorial with CNN trained on MNIST dataset. Focus on EarlyStopping. </h4>
#
# <div style="line-height:1.4; margin-bottom: 0.5em;">
#     <h3 style="color: lightblue; display: inline; margin-right: 0.5em;">Keywords:</h3>
#     pytorch_lightning.callbacks + cross_entropy + deepspeed
# </div>
#
# </div>

# %% [markdown]
# <h1 style="color:#BF66F2 ">Convolutional Neural Networks in PyTorch 6 </h1>
# <div style="margin-top: -30px;">
# <h4> PyTorch Lightning tutorial with CNN trained on MNIST dataset. Focus on EarlyStopping. </h4>
# </div>
# <div style="margin-top: -17px;">
# <span style="display: inline-block;">
#     <h3 style="color: lightblue; display: inline;">Keywords:</h3>
#     pytorch_lightning.callbacks + EarlyStopping
#     </span>
# </div>

# %% [markdown]
# <h3 style="color:#BF66F2 "> Recap: </h3>
# <div style="margin-top: -22px;">
# PyTorch Lightning is a lightweight PyTorch wrapper that simplifies the training and deployment of deep learning models, (including CNNs), providing a high-level interface and a set of abstractions. <br>
# With the goal of making the process of training CNNs more concise, modular, and reproducible, allowing users to focus more on the core model <br> architecture and training logic.
# </div>

# %%
# %%script echo Skipping, since already installed
# !pip install torchmetrics
# Out:
# Skipping, since already installed

# %%
# %%script echo Skipping, since already installed
# !pip install pytorch_lightning
# Out:
# Skipping, since already installed

# %%
import torch
import torchmetrics
from torch import nn
from torch import optim
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms

from tqdm import tqdm

import pytorch_lightning as pl
from pytorch_lightning.callbacks import Callback, EarlyStopping

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  #to ignore CUDA warnings when GPU is not in use

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
class CNNLightning(pl.LightningModule):
    """ PyTorch Lightning module for a vanilla CNN model.

    Args:
        - Learning rate for the optimizer  [float default: 3e-4]
        - Number of input channels [int default: 1]
        - Number of output classes [int default: 10]

    Details:
        - 'pl.LightningModule' is the base class for Lightning modules.
        - 'torchmetrics.Accuracy' is used to compute accuracy metric.
        - 'nn.Conv2d' is a 2D convolutional layer.
        - 'nn.MaxPool2d' is a max pooling layer.
        - 'nn.Linear' is a fully connected layer.
    """
    def __init__(self, lr=3e-4, in_channels=1, num_classes=10):
        super().__init__()
        self.lr = lr
        self.train_acc = torchmetrics.Accuracy(task="multiclass", num_classes=10)
        self.test_acc = torchmetrics.Accuracy(task="multiclass", num_classes=10)
        self.conv1 = nn.Conv2d(
            in_channels=in_channels,
            out_channels=8,
            kernel_size=3,
            stride=1,
            padding=1,
        )
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(
            in_channels=8,
            out_channels=16,
            kernel_size=3,
            stride=1,
            padding=1,
        )
        self.fc1 = nn.Linear(16 * 7 * 7, num_classes)
        self.lr = lr

    def training_step(self, batch, batch_idx):
        """ Perform a single training step.

        Parameters:
            - batch: Tuple containing input data and labels
            - Index of the current batch [int]

        Details:
            - _common_step is a helper method that computes the forward pass.
            - criterion is the loss function used for computing the loss.
            - self.log logs the training accuracy.

        Returns:
            Computed loss value for the batch
        """
        x, y = batch
        y_hat = self._common_step(x, batch_idx)
        loss = criterion(y_hat, y)
        accuracy = self.train_acc(y_hat, y)
        self.log(
            "train_acc_step",
            self.train_acc,
            on_step=True,
            on_epoch=False,
            prog_bar=True,
        )

        return loss

    def on_train_epoch_end(self):
        """ Execute at the end of each training epoch. """
        # Reset the training accuracy metric
        self.train_acc.reset()

    def test_step(self, batch, batch_idx):
        """ Perform a single test step.

        Parameters:
            batch: A tuple containing input data and labels.
            batch_idx (int): The index of the current batch.

        Details:
            - '_common_step' is a helper method that computes the forward pass.
            - 'F.cross_entropy' is the loss function used for computing the loss.
            - 'self.log' logs the test loss and accuracy.
        """
        x, y = batch
        y_hat = self._common_step(x, batch_idx)
        loss = F.cross_entropy(y_hat, y)
        accuracy = self.test_acc(y_hat, y)
        self.log("test_loss", loss, on_step=True)
        self.log("test_acc", accuracy, on_step=True)

    def validation_step(self, batch, batch_idx):
        """ Perform a single validation step.

        Parameters:
            - Tuple containing input data and labels
            - Index of the current batch [int]

        Details:
            - '_common_step' is a helper method that computes the forward pass.
            - 'F.cross_entropy' is the loss function used for computing the loss.
            - 'self.log' logs the validation loss and accuracy.
        """
        x, y = batch
        y_hat = self._common_step(x, batch_idx)
        loss = F.cross_entropy(y_hat, y)
        accuracy = self.test_acc(y_hat, y)
        self.log("val_loss", loss, on_step=True)
        self.log("val_acc", accuracy, on_step=True)

    def predict_step(self, batch, batch_idx):
        """ Perform a single prediction step.

        Parameters:
            - batch: Tuple containing input data and labels.
            - Index of the current batch [int]

        Details:
            - '_common_step' is a helper method that computes the forward pass.

        Returns:
            Predicted output for the batch (y_hat)

        """
        x, y = batch
        y_hat = self._common_step(x)
        return y_hat

    def _common_step(self, x, batch_idx):
        """ Perform the common steps of the forward pass.

        Parameters:
            - Input data
            - Index of the current batch [int]

        Details:
            - 'self.pool' applies max pooling to the input.
            - 'F.relu' applies the ReLU activation function.
            - 'x.reshape' reshapes the tensor.

        Returns:
            The predicted output (y_hat)
        """
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.reshape(x.shape[0], -1)
        y_hat = self.fc1(x)
        return y_hat

    def configure_optimizers(self):
        """ Define Adam as optimizer for the model. """
        optimizer = optim.Adam(self.parameters(), lr=self.lr)
        return optimizer

# %%
class MNISTDataModule(pl.LightningDataModule):
    """ MNISTDataModule is a PyTorch Lightning data module for loading and preprocessing MNIST dataset.

    Args:
        Batch size for the data loaders (default: 512) [int]

    Details:
        - 'pl.LightningDataModule' is the base class for Lightning data modules.
        - 'datasets.MNIST' is the MNIST dataset class from torchvision.
        - 'transforms.ToTensor()' converts the image data to tensors.
        - 'torch.utils.data.random_split' is used to split the dataset into training and validation sets.
        - 'DataLoader' is used to create data loaders for the datasets.
    """
    def __init__(self, batch_size=512):
        """ Initialize the Data Module """
        super().__init__()
        self.batch_size = batch_size

    def setup(self, stage):
        """ Set up the MNIST dataset for training, validation, and testing.

        Parameters:
            Current stage (e.g., "fit", "validate", "test").

        Details:
            'torch.utils.data.random_split' => splits the dataset into training and validation sets.
        """
        mnist_full = train_dataset = datasets.MNIST(
            root="dataset/", train=True, transform=transforms.ToTensor(), download=True)
        self.mnist_test = datasets.MNIST(
            root="dataset/", train=False, transform=transforms.ToTensor(), download=True)
        self.mnist_train, self.mnist_val = torch.utils.data.random_split(mnist_full, [55000, 5000])

    def train_dataloader(self):
        """ Create the DataLoader object for training. """
        return DataLoader(
            self.mnist_train,
            batch_size=self.batch_size,
            num_workers=6,
            shuffle=True,)

    def val_dataloader(self):
        """  Create the DataLoader object for validation. """
        return DataLoader(self.mnist_val, batch_size=self.batch_size, num_workers=2, shuffle=False)

    def test_dataloader(self):
        """ Create the DataLoader object for the test set. """
        return DataLoader(self.mnist_test, batch_size=self.batch_size, num_workers=2, shuffle=False)

# %%
class MyPrintingCallback(Callback):
    def on_train_start(self, trainer, pl_module):
        print("Training is starting")
    def on_train_epoch_end(self, trainer, pl_module):
        print("Training is ending")

# %%
precision = "medium"
torch.set_float32_matmul_precision(precision)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <h3 style="color:#BF66F2 ">  Example 1 </h3>

# %%
""" Define the Trainer with necessary arguments.
N.B.
#TypeError: Trainer.__init__() got an unexpected keyword argument 'gpus'
#trainer = pl.Trainer(
#    max_epochs = 10,
#    gpus = 1 if torch.cuda.is_available() else 0,
#    callbacks=[MyPrintingCallback()],)
"""
# Instantiate the LightningModule and LightningDataModule
model = CNNLightning()
data_module = MNISTDataModule()

trainer = pl.Trainer(max_epochs=20, accelerator="auto", callbacks=[MyPrintingCallback()],)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %% [markdown]
# <div style="line-height:0.64">
# <h3 style="color:#BF66F2 ">  Example 2 </h3>
# </div>
# Must run with GPU device, otherwise the "MisconfigurationException: No supported gpu backend found!" is raised. <br>
# from "pytorch_lightning/trainer/connectors/accelerator_connector.py".

# %%
# %%script echo Skipping, since already installed
# # To use DeepSpeedStrategy
# !pip install -U deepspeed
# Out:
# Skipping, since already installed

# %% [markdown]
# # Training strategies:
# - Training with the DistributedDataParallel strategy on many GPUs:<br>
# strategy="ddp"
#
# - Training with the DistributedDataParallel strategy on many GPUs, with options configured:<br>
# strategy=DDPStrategy(static_graph=True)
#
# - Training with the DDP Spawn strategy: <br>
# strategy="ddp_spawn
#
# - Training with the DeepSpeed strategy on available GPUs: <br>
# strategy="deepspeed"
#
# => On Colab use: strategy="ddp_notebook"

# %%
# %%script echo Skipping, since already installed
# !pip install "ray[tune]"
# Out:
# Skipping, since already installed

# %%
# %%script echo Skipping, since already installed
# !pip install "pytorch-lightning-bolts>=0.2.5"
# Out:
# Skipping, since already installed

# %%
import os
import torch
from torch.nn import functional as F
import pytorch_lightning as pl
from ray.tune.integration.pytorch_lightning import TuneReportCallback

# %%
# %%script echo Skipping, since useless
# """ Use 20% of training data for validation. """
# train_set_size = int(len(train_dataset) * 0.8)
# valid_set_size = len(train_dataset) - train_set_size
#
# """ Split the train set into two """
# seed = torch.Generator().manual_seed(42)
# train_dataset, val_dataset = torch.utils.data.random_split(
#     train_dataset, [train_set_size, valid_set_size], generator=seed)
# Out:
# Skipping, since useless

# %%
# Initialize network
model_lightning = CNNLightning()

trainer = pl.Trainer(
    #fast_dev_run=True,
    # overfit_batches=3,
    max_epochs=5,
    precision='16-mixed',           #16 is supported for historical reasons but its usage is discouraged
    accelerator="gpu",
    #devices=[0,1],                 #in case of more GPUs are available
    devices=[0],
    callbacks=[EarlyStopping(monitor="val_loss", mode="min")],
    enable_model_summary=True,
    profiler="simple",
    strategy="ddp_notebook",
)

dm = MNISTDataModule()
trainer.fit(model=model_lightning, datamodule=dm,)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:lightning_fabric.utilities.distributed:Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# INFO:pytorch_lightning.utilities.rank_zero:----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params
# -------------------------------------------------
# 0 | train_acc | MulticlassAccuracy | 0
# 1 | test_acc  | MulticlassAccuracy | 0
# 2 | conv1     | Conv2d             | 80
# 3 | pool      | MaxPool2d          | 0
# 4 | conv2     | Conv2d             | 1.2 K
# 5 | fc1       | Linear             | 7.9 K
# -------------------------------------------------
# 9.1 K     Trainable params
# 0         Non-trainable params
# 9.1 K     Total params
# 0.036     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:432: PossibleUserWarning: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#   warning_cache.warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:432: PossibleUserWarning: It is recommended to use `self.log('val_acc', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#   warning_cache.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.
# INFO:pytorch_lightning.profilers.profiler:FIT Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                         	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                          	|  -              	|  23791          	|  58.94          	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                             	|  8.2183         	|  5              	|  41.092         	|  69.718         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                     	|  0.031495       	|  540            	|  17.007         	|  28.855         	|
# |  run_training_batch                                                                                                                                             	|  0.022534       	|  540            	|  12.169         	|  20.646         	|
# |  [LightningModule]CNNLightning.optimizer_step                                                                                                                   	|  0.022329       	|  540            	|  12.057         	|  20.457         	|
# |  [Strategy]DDPStrategy.training_step                                                                                                                            	|  0.010036       	|  540            	|  5.4192         	|  9.1945         	|
# |  [Strategy]DDPStrategy.backward                                                                                                                                 	|  0.0072835      	|  540            	|  3.9331         	|  6.6731         	|
# |  [_EvaluationLoop].val_next                                                                                                                                     	|  0.033158       	|  53             	|  1.7574         	|  2.9817         	|
# |  [Strategy]DDPStrategy.validation_step                                                                                                                          	|  0.032552       	|  52             	|  1.6927         	|  2.8719         	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                   	|  0.0028259      	|  540            	|  1.526          	|  2.5891         	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                  	|  0.14236        	|  6              	|  0.85415        	|  1.4492         	|
# |  [Strategy]DDPStrategy.batch_to_device                                                                                                                          	|  0.001245       	|  592            	|  0.73701        	|  1.2504         	|
# |  [LightningModule]CNNLightning.transfer_batch_to_device                                                                                                         	|  0.0010612      	|  592            	|  0.62825        	|  1.0659         	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                            	|  0.0042688      	|  52             	|  0.22198        	|  0.37661        	|
# |  [LightningModule]CNNLightning.optimizer_zero_grad                                                                                                              	|  0.00035018     	|  540            	|  0.1891         	|  0.32083        	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                	|  0.087255       	|  1              	|  0.087255       	|  0.14804        	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                              	|  0.0013581      	|  52             	|  0.070624       	|  0.11982        	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                       	|  0.068739       	|  1              	|  0.068739       	|  0.11663        	|
# |  [LightningDataModule]MNISTDataModule.setup                                                                                                                     	|  0.062322       	|  1              	|  0.062322       	|  0.10574        	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                 	|  0.01203        	|  5              	|  0.060148       	|  0.10205        	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                    	|  0.0094311      	|  6              	|  0.056586       	|  0.096007       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_end       	|  0.0094068      	|  5              	|  0.047034       	|  0.0798         	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_end       	|  7.5078e-05     	|  540            	|  0.040542       	|  0.068786       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_zero_grad                                                                              	|  5.1135e-05     	|  540            	|  0.027613       	|  0.046849       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_backward                                                                               	|  4.6324e-05     	|  540            	|  0.025015       	|  0.042441       	|
# |  [LightningModule]CNNLightning.configure_gradient_clipping                                                                                                      	|  3.8112e-05     	|  540            	|  0.02058        	|  0.034918       	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                   	|  0.0027868      	|  5              	|  0.013934       	|  0.023641       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_zero_grad      	|  2.4249e-05     	|  540            	|  0.013094       	|  0.022217       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_end                                                                               	|  0.0016994      	|  5              	|  0.0084971      	|  0.014416       	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                         	|  0.0056828      	|  1              	|  0.0056828      	|  0.0096417      	|
# |  [LightningDataModule]MNISTDataModule.train_dataloader                                                                                                          	|  0.0043132      	|  1              	|  0.0043132      	|  0.007318       	|
# |  [LightningModule]CNNLightning.on_validation_model_eval                                                                                                         	|  0.0006465      	|  6              	|  0.003879       	|  0.0065813      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_start                                                                             	|  6.4527e-06     	|  540            	|  0.0034845      	|  0.0059119      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_optimizer_step                                                                         	|  5.7838e-06     	|  540            	|  0.0031232      	|  0.005299       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_after_backward                                                                                	|  4.4217e-06     	|  540            	|  0.0023877      	|  0.0040511      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_end                                                                               	|  3.9815e-06     	|  540            	|  0.00215        	|  0.0036478      	|
# |  [LightningModule]CNNLightning.on_after_batch_transfer                                                                                                          	|  3.6125e-06     	|  592            	|  0.0021386      	|  0.0036284      	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                            	|  0.0018108      	|  1              	|  0.0018108      	|  0.0030724      	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                       	|  3.2855e-06     	|  540            	|  0.0017742      	|  0.0030102      	|
# |  [LightningModule]CNNLightning.on_before_batch_transfer                                                                                                         	|  2.9584e-06     	|  592            	|  0.0017514      	|  0.0029714      	|
# |  [LightningModule]CNNLightning.on_train_epoch_end                                                                                                               	|  0.00032804     	|  5              	|  0.0016402      	|  0.0027828      	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                    	|  2.4176e-06     	|  540            	|  0.0013055      	|  0.0022149      	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                             	|  2.3696e-06     	|  540            	|  0.0012796      	|  0.002171       	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                  	|  2.3252e-06     	|  540            	|  0.0012556      	|  0.0021303      	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                      	|  2.2753e-06     	|  540            	|  0.0012286      	|  0.0020846      	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                 	|  2.2413e-06     	|  540            	|  0.0012103      	|  0.0020535      	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                   	|  2.2219e-06     	|  540            	|  0.0011998      	|  0.0020357      	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                     	|  2.0921e-06     	|  540            	|  0.0011297      	|  0.0019168      	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                    	|  2.0518e-06     	|  540            	|  0.001108       	|  0.0018798      	|
# |  [LightningModule]CNNLightning.on_before_zero_grad                                                                                                              	|  2.0277e-06     	|  540            	|  0.0010949      	|  0.0018577      	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                	|  2.025e-06      	|  540            	|  0.0010935      	|  0.0018553      	|
# |  [LightningModule]CNNLightning.on_before_optimizer_step                                                                                                         	|  2.0134e-06     	|  540            	|  0.0010872      	|  0.0018446      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_after_backward        	|  2.0116e-06     	|  540            	|  0.0010863      	|  0.001843       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_start     	|  2.0017e-06     	|  540            	|  0.0010809      	|  0.0018339      	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                      	|  1.9876e-06     	|  540            	|  0.0010733      	|  0.001821       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_optimizer_step 	|  1.9609e-06     	|  540            	|  0.0010589      	|  0.0017966      	|
# |  [LightningModule]CNNLightning.on_train_batch_start                                                                                                             	|  1.9215e-06     	|  540            	|  0.0010376      	|  0.0017605      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_backward       	|  1.8494e-06     	|  540            	|  0.00099867     	|  0.0016944      	|
# |  [LightningModule]CNNLightning.on_after_backward                                                                                                                	|  1.8285e-06     	|  540            	|  0.00098739     	|  0.0016752      	|
# |  [LightningModule]CNNLightning.on_train_batch_end                                                                                                               	|  1.7738e-06     	|  540            	|  0.00095784     	|  0.0016251      	|
# |  [LightningModule]CNNLightning.on_before_backward                                                                                                               	|  1.7731e-06     	|  540            	|  0.00095748     	|  0.0016245      	|
# |  [Strategy]DDPStrategy.on_train_batch_start                                                                                                                     	|  1.5034e-06     	|  540            	|  0.00081186     	|  0.0013774      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                    	|  0.00077464     	|  1              	|  0.00077464     	|  0.0013143      	|
# |  [LightningModule]CNNLightning.on_validation_model_train                                                                                                        	|  0.00011691     	|  6              	|  0.00070146     	|  0.0011901      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_end        	|  8.7346e-05     	|  6              	|  0.00052408     	|  0.00088917     	|
# |  [LightningDataModule]MNISTDataModule.val_dataloader                                                                                                            	|  0.00043062     	|  1              	|  0.00043062     	|  0.00073061     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_end                                                                          	|  4.9725e-06     	|  52             	|  0.00025857     	|  0.0004387      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_start                                                                        	|  3.7663e-06     	|  52             	|  0.00019585     	|  0.00033229     	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                 	|  2.6003e-06     	|  52             	|  0.00013522     	|  0.00022941     	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                               	|  2.4178e-06     	|  52             	|  0.00012573     	|  0.00021332     	|
# |  [LightningModule]CNNLightning.configure_optimizers                                                                                                             	|  0.00012495     	|  1              	|  0.00012495     	|  0.000212       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_end  	|  2.0912e-06     	|  52             	|  0.00010874     	|  0.0001845      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_start	|  1.954e-06      	|  52             	|  0.00010161     	|  0.00017239     	|
# |  [LightningModule]CNNLightning.on_validation_batch_start                                                                                                        	|  1.9156e-06     	|  52             	|  9.9609e-05     	|  0.000169       	|
# |  [LightningModule]CNNLightning.on_validation_batch_end                                                                                                          	|  1.8973e-06     	|  52             	|  9.8662e-05     	|  0.00016739     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_end                                                                                	|  1.2329e-05     	|  6              	|  7.3975e-05     	|  0.00012551     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                     	|  1.1895e-05     	|  6              	|  7.1372e-05     	|  0.00012109     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_start                                                                              	|  1.1595e-05     	|  6              	|  6.9568e-05     	|  0.00011803     	|
# |  [Strategy]DDPStrategy.on_validation_start                                                                                                                      	|  6.9665e-06     	|  6              	|  4.1799e-05     	|  7.0918e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                      	|  7.0406e-06     	|  5              	|  3.5203e-05     	|  5.9727e-05     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                       	|  4.9602e-06     	|  6              	|  2.9761e-05     	|  5.0494e-05     	|
# |  [LightningModule]CNNLightning.configure_callbacks                                                                                                              	|  2.8779e-05     	|  1              	|  2.8779e-05     	|  4.8828e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                    	|  5.4006e-06     	|  5              	|  2.7003e-05     	|  4.5814e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_end                                                                          	|  3.8662e-06     	|  6              	|  2.3197e-05     	|  3.9357e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_start      	|  3.527e-06      	|  6              	|  2.1162e-05     	|  3.5904e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_start                                                                        	|  3.2113e-06     	|  6              	|  1.9268e-05     	|  3.2691e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_start                                                                             	|  3.6476e-06     	|  5              	|  1.8238e-05     	|  3.0943e-05     	|
# |  [LightningModule]CNNLightning.on_validation_start                                                                                                              	|  3.0153e-06     	|  6              	|  1.8092e-05     	|  3.0696e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_save_checkpoint                                                                               	|  2.9704e-06     	|  5              	|  1.4852e-05     	|  2.5199e-05     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                	|  1.4062e-05     	|  1              	|  1.4062e-05     	|  2.3858e-05     	|
# |  [LightningDataModule]MNISTDataModule.state_dict                                                                                                                	|  2.7896e-06     	|  5              	|  1.3948e-05     	|  2.3665e-05     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                           	|  1.3235e-05     	|  1              	|  1.3235e-05     	|  2.2455e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                            	|  2.1467e-06     	|  6              	|  1.288e-05      	|  2.1853e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                               	|  2.0913e-06     	|  6              	|  1.2548e-05     	|  2.1289e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start     	|  2.3922e-06     	|  5              	|  1.1961e-05     	|  2.0294e-05     	|
# |  [LightningModule]CNNLightning.on_validation_end                                                                                                                	|  1.9757e-06     	|  6              	|  1.1854e-05     	|  2.0112e-05     	|
# |  [LightningModule]CNNLightning.on_fit_start                                                                                                                     	|  1.1479e-05     	|  1              	|  1.1479e-05     	|  1.9476e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start	|  1.8798e-06     	|  6              	|  1.1279e-05     	|  1.9136e-05     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                   	|  2.168e-06      	|  5              	|  1.084e-05      	|  1.8392e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                              	|  1.7618e-06     	|  6              	|  1.0571e-05     	|  1.7935e-05     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                   	|  1.0363e-05     	|  1              	|  1.0363e-05     	|  1.7582e-05     	|
# |  [LightningModule]CNNLightning.on_validation_epoch_start                                                                                                        	|  1.6792e-06     	|  6              	|  1.0075e-05     	|  1.7094e-05     	|
# |  [LightningModule]CNNLightning.on_train_epoch_start                                                                                                             	|  1.9794e-06     	|  5              	|  9.897e-06      	|  1.6792e-05     	|
# |  [Strategy]DDPStrategy.on_validation_end                                                                                                                        	|  1.6207e-06     	|  6              	|  9.724e-06      	|  1.6498e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                 	|  1.5917e-06     	|  6              	|  9.55e-06       	|  1.6203e-05     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                      	|  1.7902e-06     	|  5              	|  8.951e-06      	|  1.5187e-05     	|
# |  [LightningModule]CNNLightning.on_validation_epoch_end                                                                                                          	|  1.4857e-06     	|  6              	|  8.914e-06      	|  1.5124e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint       	|  1.7732e-06     	|  5              	|  8.866e-06      	|  1.5042e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end  	|  1.4667e-06     	|  6              	|  8.8e-06        	|  1.493e-05      	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                          	|  8.297e-06      	|  1              	|  8.297e-06      	|  1.4077e-05     	|
# |  [LightningModule]CNNLightning.configure_sharded_model                                                                                                          	|  7.444e-06      	|  1              	|  7.444e-06      	|  1.263e-05      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                            	|  7.271e-06      	|  1              	|  7.271e-06      	|  1.2336e-05     	|
# |  [LightningModule]CNNLightning.on_save_checkpoint                                                                                                               	|  1.31e-06       	|  5              	|  6.55e-06       	|  1.1113e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start             	|  6.074e-06      	|  1              	|  6.074e-06      	|  1.0305e-05     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                  	|  5.376e-06      	|  1              	|  5.376e-06      	|  9.1212e-06     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                            	|  5.047e-06      	|  1              	|  5.047e-06      	|  8.563e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start           	|  5.016e-06      	|  1              	|  5.016e-06      	|  8.5104e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_start                                                                            	|  4.922e-06      	|  1              	|  4.922e-06      	|  8.3509e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_end                                                                                       	|  4.64e-06       	|  1              	|  4.64e-06       	|  7.8724e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_end                                                                                     	|  4.578e-06      	|  1              	|  4.578e-06      	|  7.7672e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_start                                                                                   	|  3.326e-06      	|  1              	|  3.326e-06      	|  5.643e-06      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_start                                                                                     	|  3.21e-06       	|  1              	|  3.21e-06       	|  5.4462e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_end                                                                              	|  2.935e-06      	|  1              	|  2.935e-06      	|  4.9797e-06     	|
# |  [LightningModule]CNNLightning.setup                                                                                                                            	|  2.567e-06      	|  1              	|  2.567e-06      	|  4.3553e-06     	|
# |  [LightningDataModule]MNISTDataModule.prepare_data                                                                                                              	|  2.553e-06      	|  1              	|  2.553e-06      	|  4.3315e-06     	|
# |  [Strategy]DDPStrategy.on_train_start                                                                                                                           	|  2.363e-06      	|  1              	|  2.363e-06      	|  4.0092e-06     	|
# |  [LightningModule]CNNLightning.on_train_start                                                                                                                   	|  2.296e-06      	|  1              	|  2.296e-06      	|  3.8955e-06     	|
# |  [LightningModule]CNNLightning.on_train_end                                                                                                                     	|  2.273e-06      	|  1              	|  2.273e-06      	|  3.8565e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end             	|  2.227e-06      	|  1              	|  2.227e-06      	|  3.7784e-06     	|
# |  [Callback]ModelSummary.setup                                                                                                                                   	|  2.126e-06      	|  1              	|  2.126e-06      	|  3.6071e-06     	|
# |  [Strategy]DDPStrategy.on_train_end                                                                                                                             	|  1.81e-06       	|  1              	|  1.81e-06       	|  3.0709e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                     	|  1.749e-06      	|  1              	|  1.749e-06      	|  2.9674e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                         	|  1.725e-06      	|  1              	|  1.725e-06      	|  2.9267e-06     	|
# |  [LightningDataModule]MNISTDataModule.teardown                                                                                                                  	|  1.624e-06      	|  1              	|  1.624e-06      	|  2.7553e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start    	|  1.517e-06      	|  1              	|  1.517e-06      	|  2.5738e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                         	|  1.511e-06      	|  1              	|  1.511e-06      	|  2.5636e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end      	|  1.472e-06      	|  1              	|  1.472e-06      	|  2.4975e-06     	|
# |  [LightningModule]CNNLightning.on_fit_end                                                                                                                       	|  1.289e-06      	|  1              	|  1.289e-06      	|  2.187e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                 	|  1.257e-06      	|  1              	|  1.257e-06      	|  2.1327e-06     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                              	|  1.243e-06      	|  1              	|  1.243e-06      	|  2.1089e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                	|  1.225e-06      	|  1              	|  1.225e-06      	|  2.0784e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                             	|  1.173e-06      	|  1              	|  1.173e-06      	|  1.9902e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end               	|  1.144e-06      	|  1              	|  1.144e-06      	|  1.941e-06      	|
# |  [LightningModule]CNNLightning.prepare_data                                                                                                                     	|  9.32e-07       	|  1              	|  9.32e-07       	|  1.5813e-06     	|
# |  [LightningModule]CNNLightning.teardown                                                                                                                         	|  9.3e-07        	|  1              	|  9.3e-07        	|  1.5779e-06     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Tune the trainer first to find best batch size and lr
#trainer.tune(model_lightning, dm)

# Train the model


# Test model on test loader from LightningDataModule
trainer.test(model=model_lightning, datamodule=dm)
# Out:
# INFO:lightning_fabric.utilities.distributed:Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# INFO:pytorch_lightning.utilities.rank_zero:----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:432: PossibleUserWarning: It is recommended to use `self.log('test_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#   warning_cache.warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:432: PossibleUserWarning: It is recommended to use `self.log('test_acc', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#   warning_cache.warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │      test_acc_epoch       │    0.9337999820709229     │
# │      test_loss_epoch      │    0.2383224368095398     │
# └───────────────────────────┴───────────────────────────┘
# INFO:pytorch_lightning.profilers.profiler:TEST Profiler Report
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                   	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                    	|  -              	|  361            	|  68.987         	|  100 %          	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  [Strategy]DDPStrategy.test_step                                                                                                                          	|  0.075128       	|  20             	|  1.5026         	|  2.178          	|
# |  [_EvaluationLoop].test_next                                                                                                                              	|  0.026872       	|  20             	|  0.53744        	|  0.77904        	|
# |  [Callback]TQDMProgressBar.on_test_start                                                                                                                  	|  0.20604        	|  1              	|  0.20604        	|  0.29866        	|
# |  [LightningDataModule]MNISTDataModule.setup                                                                                                               	|  0.064221       	|  1              	|  0.064221       	|  0.093091       	|
# |  [Callback]TQDMProgressBar.on_test_batch_start                                                                                                            	|  0.0031719      	|  20             	|  0.063438       	|  0.091956       	|
# |  [Strategy]DDPStrategy.batch_to_device                                                                                                                    	|  0.00092621     	|  20             	|  0.018524       	|  0.026852       	|
# |  [LightningModule]CNNLightning.transfer_batch_to_device                                                                                                   	|  0.00079718     	|  20             	|  0.015944       	|  0.023111       	|
# |  [Callback]TQDMProgressBar.on_test_batch_end                                                                                                              	|  0.00029291     	|  20             	|  0.0058582      	|  0.0084918      	|
# |  [Callback]TQDMProgressBar.on_test_end                                                                                                                    	|  0.0049663      	|  1              	|  0.0049663      	|  0.0071989      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup              	|  0.00069482     	|  1              	|  0.00069482     	|  0.0010072      	|
# |  [LightningDataModule]MNISTDataModule.test_dataloader                                                                                                     	|  0.0006004      	|  1              	|  0.0006004      	|  0.00087031     	|
# |  [LightningModule]CNNLightning.on_test_model_eval                                                                                                         	|  0.00045159     	|  1              	|  0.00045159     	|  0.0006546      	|
# |  [LightningModule]CNNLightning.on_test_model_train                                                                                                        	|  9.914e-05      	|  1              	|  9.914e-05      	|  0.00014371     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_batch_end                                                                          	|  3.8958e-06     	|  20             	|  7.7917e-05     	|  0.00011294     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_batch_start                                                                        	|  3.7773e-06     	|  20             	|  7.5546e-05     	|  0.00010951     	|
# |  [LightningModule]CNNLightning.on_before_batch_transfer                                                                                                   	|  2.8415e-06     	|  20             	|  5.6829e-05     	|  8.2376e-05     	|
# |  [Callback]ModelSummary.on_test_batch_start                                                                                                               	|  2.4657e-06     	|  20             	|  4.9315e-05     	|  7.1485e-05     	|
# |  [LightningModule]CNNLightning.on_after_batch_transfer                                                                                                    	|  2.4258e-06     	|  20             	|  4.8516e-05     	|  7.0326e-05     	|
# |  [Callback]ModelSummary.on_test_batch_end                                                                                                                 	|  2.3146e-06     	|  20             	|  4.6293e-05     	|  6.7104e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_start	|  2.1755e-06     	|  20             	|  4.3511e-05     	|  6.3071e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_end  	|  2.0311e-06     	|  20             	|  4.0622e-05     	|  5.8884e-05     	|
# |  [LightningModule]CNNLightning.on_test_batch_end                                                                                                          	|  1.7036e-06     	|  20             	|  3.4072e-05     	|  4.9389e-05     	|
# |  [LightningModule]CNNLightning.on_test_batch_start                                                                                                        	|  1.6588e-06     	|  20             	|  3.3175e-05     	|  4.8089e-05     	|
# |  [LightningModule]CNNLightning.configure_callbacks                                                                                                        	|  2.4313e-05     	|  1              	|  2.4313e-05     	|  3.5243e-05     	|
# |  [Callback]ModelSummary.on_test_start                                                                                                                     	|  1.9642e-05     	|  1              	|  1.9642e-05     	|  2.8472e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_start                                                                              	|  1.1856e-05     	|  1              	|  1.1856e-05     	|  1.7186e-05     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                          	|  1.0971e-05     	|  1              	|  1.0971e-05     	|  1.5903e-05     	|
# |  [LightningModule]CNNLightning.configure_sharded_model                                                                                                    	|  9.51e-06       	|  1              	|  9.51e-06       	|  1.3785e-05     	|
# |  [Strategy]DDPStrategy.on_test_start                                                                                                                      	|  8.038e-06      	|  1              	|  8.038e-06      	|  1.1651e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                      	|  7.024e-06      	|  1              	|  7.024e-06      	|  1.0182e-05     	|
# |  [Callback]ModelSummary.on_test_end                                                                                                                       	|  5.094e-06      	|  1              	|  5.094e-06      	|  7.384e-06      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_epoch_end                                                                          	|  4.539e-06      	|  1              	|  4.539e-06      	|  6.5795e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_start      	|  3.839e-06      	|  1              	|  3.839e-06      	|  5.5648e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_epoch_start                                                                        	|  3.58e-06       	|  1              	|  3.58e-06       	|  5.1894e-06     	|
# |  [Callback]ModelSummary.setup                                                                                                                             	|  3.556e-06      	|  1              	|  3.556e-06      	|  5.1546e-06     	|
# |  [LightningDataModule]MNISTDataModule.teardown                                                                                                            	|  3.495e-06      	|  1              	|  3.495e-06      	|  5.0662e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                   	|  3.06e-06       	|  1              	|  3.06e-06       	|  4.4356e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_end                                                                                	|  2.947e-06      	|  1              	|  2.947e-06      	|  4.2718e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_end                                                                                                              	|  2.673e-06      	|  1              	|  2.673e-06      	|  3.8746e-06     	|
# |  [LightningModule]CNNLightning.setup                                                                                                                      	|  2.522e-06      	|  1              	|  2.522e-06      	|  3.6558e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_end        	|  2.439e-06      	|  1              	|  2.439e-06      	|  3.5355e-06     	|
# |  [Callback]ModelSummary.on_test_epoch_end                                                                                                                 	|  2.41e-06       	|  1              	|  2.41e-06       	|  3.4934e-06     	|
# |  [LightningDataModule]MNISTDataModule.prepare_data                                                                                                        	|  2.341e-06      	|  1              	|  2.341e-06      	|  3.3934e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_end  	|  2.139e-06      	|  1              	|  2.139e-06      	|  3.1006e-06     	|
# |  [LightningModule]CNNLightning.on_test_start                                                                                                              	|  2.13e-06       	|  1              	|  2.13e-06       	|  3.0875e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                            	|  2.073e-06      	|  1              	|  2.073e-06      	|  3.0049e-06     	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                               	|  1.978e-06      	|  1              	|  1.978e-06      	|  2.8672e-06     	|
# |  [Strategy]DDPStrategy.on_test_end                                                                                                                        	|  1.902e-06      	|  1              	|  1.902e-06      	|  2.757e-06      	|
# |  [LightningModule]CNNLightning.on_test_end                                                                                                                	|  1.88e-06       	|  1              	|  1.88e-06       	|  2.7252e-06     	|
# |  [LightningModule]CNNLightning.on_test_epoch_start                                                                                                        	|  1.871e-06      	|  1              	|  1.871e-06      	|  2.7121e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_start	|  1.859e-06      	|  1              	|  1.859e-06      	|  2.6947e-06     	|
# |  [LightningModule]CNNLightning.on_test_epoch_end                                                                                                          	|  1.804e-06      	|  1              	|  1.804e-06      	|  2.615e-06      	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                       	|  1.693e-06      	|  1              	|  1.693e-06      	|  2.4541e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown           	|  1.388e-06      	|  1              	|  1.388e-06      	|  2.012e-06      	|
# |  [Callback]ModelSummary.teardown                                                                                                                          	|  1.326e-06      	|  1              	|  1.326e-06      	|  1.9221e-06     	|
# |  [LightningModule]CNNLightning.teardown                                                                                                                   	|  1.114e-06      	|  1              	|  1.114e-06      	|  1.6148e-06     	|
# |  [LightningModule]CNNLightning.prepare_data                                                                                                               	|  1.039e-06      	|  1              	|  1.039e-06      	|  1.5061e-06     	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [{'test_loss_epoch': 0.2383224368095398, 'test_acc_epoch': 0.9337999820709229}]
